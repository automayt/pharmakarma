# %%
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:

# conda install lxml
# conda install html5lib
# conda install BeautifulSoup4
# Then restart Jupyter Notebook. (or use pip install if you aren't using the Anaconda Distribution)

import numpy as np
import pandas as pd
import os.path
from datetime import datetime, timedelta

one_hour_ago = datetime.now() - timedelta(hours=1)
if os.path.exists("history.csv"):
    filetime = datetime.fromtimestamp(os.path.getctime("history.csv"))
    if filetime < one_hour_ago:
        histdata = pd.read_html("https://www.biopharmcatalyst.com/calendars/historical-catalyst-calendar")
        histdata[0].to_csv('history.csv',index=False)
else:
    histdata = pd.read_html("https://www.biopharmcatalyst.com/calendars/historical-catalyst-calendar")
    histdata[0].to_csv('history.csv',index=False)

df = pd.read_csv('history.csv').set_index('Ticker')
df.index.name=None

df[["Date","Catalyst"]] = df.Catalyst.str.extract('(?P<Date>[0-9]{2}\/[0-9]{2}\/[0-9]{4})(?P<Catalyst>.*)', expand=True)

df.loc["OCUL"]
# Out:
#                                                    Drug     Stage  \
# OCUL                  DEXTENZA  Allergic conjunctivitis   Phase 3
# OCUL  DEXTENZA  Ocular inflammation and pain followi...  Approved
# OCUL  DEXTENZA  Ocular inflammation and pain followi...  Approved
# OCUL  DEXTENZA  Ocular inflammation and pain followi...  Approved
#
#                                                Catalyst        Date
# OCUL    Phase 3 trial did not meet primary endpoint ...  06/06/2016
# OCUL    CRL July 25 2016 - due to manufacturing defi...  07/25/2016
# OCUL    CRL July 25 2016 - due to manufacturing defi...  07/11/2017
# OCUL           FDA approval announced December 3, 2018.  12/03/2018

# %%
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:

# conda install lxml
# conda install html5lib
# conda install BeautifulSoup4
# Then restart Jupyter Notebook. (or use pip install if you aren't using the Anaconda Distribution)
import numpy as np
import pandas as pd
import os.path
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.parser import parse
from dateutil.relativedelta import relativedelta
from pandas.tseries.offsets import *
from pylab import text
from mpl_toolkits.axes_grid.anchored_artists import AnchoredText
import quandl


# Quandl API key
quandl.ApiConfig.api_key = "UsYsv7dKGxHHQ5oURP4B"

# Some formatting
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_seq_items', 2)

# Only pull fresh PDUFA data
three_weeks_ago = relativedelta(weeks=3)
one_week_ahead = relativedelta(weeks=1)
one_hour_ago = datetime.now() - timedelta(hours=1)
if os.path.exists("history.csv"):
    filetime = datetime.fromtimestamp(os.path.getctime("history.csv"))
    if filetime < one_hour_ago:
        histdata = pd.read_html("https://www.biopharmcatalyst.com/calendars/historical-catalyst-calendar")
        histdata[0].to_csv('history.csv',index=False)
else:
    histdata = pd.read_html("https://www.biopharmcatalyst.com/calendars/historical-catalyst-calendar")
    histdata[0].to_csv('history.csv',index=False)

# Create dataframe
df = pd.read_csv('history.csv').set_index('Ticker')
df.index.name=None
df[["Date","Catalyst"]] = df.Catalyst.str.extract('(?P<Date>[0-9]{2}\/[0-9]{2}\/[0-9]{4})(?P<Catalyst>.*)', expand=True)
df['Date'] = pd.to_datetime(df['Date'])
df["Past"] = df["Date"] - DateOffset(weeks=3)
df["Future"] = df["Date"] + DateOffset(weeks=1)

df
# Set stock ticker
stockpick="HALO"
dataset=str(f"WIKI/{stockpick}")
# Set variables for plot creation
length = len(df.loc[stockpick].index)
count = 0
fig, axes = plt.subplots(nrows=length, ncols=1,figsize=(16,length * 3))
fig.subplots_adjust(hspace=0, wspace=0)
allplots=[]

# Combine all data together into list of dataframes, iterate through each part of the list, plot each frame.
while (count < length):
    pasttime= df.loc[stockpick].iloc[count]["Past"]
    futuretime= df.loc[stockpick].iloc[count]["Future"]
    pdufa=df.loc[stockpick].iloc[count]["Date"]
    annotate = df.loc[stockpick].iloc[count]["Date"] + timedelta(days=1)
    stage = df.loc[stockpick].iloc[count]["Stage"]
    catalyst = df.loc[stockpick].iloc[count]["Catalyst"]
    drug = df.loc[stockpick].iloc[count]["Drug"]
    
    #Annotation
    tooltip = f"stage:{stage}\n{drug}"
    at = AnchoredText(tooltip,
                      prop=dict(size=10), frameon=True,
                      loc=2, 
                      )
    at.patch.set_boxstyle("round,pad=0.2,rounding_size=0.2")
    axes[count].add_artist(at)
    axes[count].margins(0.0, 1.5)

    
    #Get quandl data
    mydata = quandl.get(dataset,start_date=pasttime,end_date=futuretime)
    allplots.append(mydata)
#     axes[count].annotate('local max', xy=(pdufa, allplots[count]["Close"].max()), xytext=(annotate, (allplots[count]["Close"].max() - allplots[count]["Close"].min()) * 0.9 + allplots[count]["Close"].min()),
#             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5),)
    axes[count].vlines(pdufa, allplots[count]["Close"].min(), allplots[count]["Close"].max(), linestyle="--", color='black')
    axes[count].plot(allplots[count].index,allplots[count]["Close"],c=np.random.rand(3,), lw=2, label=pdufa) 
    axes[count].axes.get_xaxis().set_visible(False) # remove x axis
    count = count + 1
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(2, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5),
            )

ax.annotate('local min', xy=(1.5, -1), xytext=(1, -1.5),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=5),
            )

ax.set_ylim(-2,2)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.anchored_artists import AnchoredText

fig=plt.figure(1, figsize=(3,3))
ax = plt.subplot(111)

at = AnchoredText("Figure 1a",
                  prop=dict(size=15), frameon=True,
                  loc=2, 
                  )
at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
ax.add_artist(at)

plt.show()

# %%
# conda install BeautifulSoup4
# Then restart Jupyter Notebook. (or use pip install if you aren't using the Anaconda Distribution)
import numpy as np
import pandas as pd
import os.path
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.parser import parse
from dateutil.relativedelta import relativedelta
from pandas.tseries.offsets import *
from pylab import text
from mpl_toolkits.axes_grid.anchored_artists import AnchoredText
import quandl


# Quandl API key
quandl.ApiConfig.api_key = "UsYsv7dKGxHHQ5oURP4B"

# Some formatting
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_seq_items', 2)

# Only pull fresh PDUFA data
three_weeks_ago = relativedelta(weeks=3)
one_week_ahead = relativedelta(weeks=1)
one_hour_ago = datetime.now() - timedelta(hours=1)
if os.path.exists("history.csv"):
    filetime = datetime.fromtimestamp(os.path.getctime("history.csv"))
    if filetime < one_hour_ago:
        histdata = pd.read_html("https://www.biopharmcatalyst.com/calendars/historical-catalyst-calendar")
        histdata[0].to_csv('history.csv',index=False)
else:
    histdata = pd.read_html("https://www.biopharmcatalyst.com/calendars/historical-catalyst-calendar")
    histdata[0].to_csv('history.csv',index=False)

# Create dataframe
df = pd.read_csv('history.csv').set_index('Ticker')
df.index.name=None
df[["Date","Catalyst"]] = df.Catalyst.str.extract('(?P<Date>[0-9]{2}\/[0-9]{2}\/[0-9]{4})(?P<Catalyst>.*)', expand=True)
df['Date'] = pd.to_datetime(df['Date'])
df["Past"] = df["Date"] - DateOffset(weeks=3)
df["Future"] = df["Date"] + DateOffset(weeks=1)

df
# Out:
#                                                                                                                                                           Drug  \
# SPPI   ZEVALIN  Non-Hodgkin’s lymphoma
# ZGNX   Sumavel  Migraine
# ARDM   Sumavel  Migraine
# SPPI   ZEVALIN  Non-Hodgkin’s lymphoma
# SPPI   FUSILEV  Colorectal cancer
# PRTK   Intermezzo  Insomnia
# GTXI   Toremifene  Reduce fractures in men with prostate cancer
# HEB    Ampligen  CFS
# FCSC   Laviv  Wrinkles
# ACOR   Ampyra  Improve walking in patients with multiple sclerosis
# ALKS   BYDUREON  Type 2 diabetes
# MNKD   AFREZZA Type 1/2 diabetes
# ALKS   BYDUREON  Type 2 diabetes
# HRTX   APF530 - Sustol  Prevention of acute- and delayed-onset chemotherapy-induced nausea and vomiting (CINV)
# CTIC   PIXUVRI - PIX306 Trial  B-cell non-Hodgkin lymphoma
# ARLZ   VIMOVO  Gastric ulcers
# JAZZ   JZP-6  Fibromyalgia
# VVUS   Qnexa  Obesity
# MNKD   AFREZZA Type 1/2 diabetes
# DEPO   GRALISE  Postherpetic neuralgia - shingles
# PLX    Taliglucerase alfa  Gaucher disease
# SPPI   FUSILEV  Colorectal cancer
# FCSC   Laviv  Wrinkles
# DRRX   Remoxy  Chronic pain
# PTIE   Remoxy  Chronic pain
# SGEN   ADCETRIS  Hodgkin lymphoma and Anaplastic large cell lymphoma
# PCRX   EXPAREL  Postsurgical pain
# ALIM   Iluvien  Diabetic macular edema
# INCY   Jakafi  Myelofibrosis
# PRTK   Intermezzo  Insomnia
# ...                     ...
# ARQL   ARQ 751  Solid tumors
# AQST   AQST-119  Erectile dysfunction
# TCON   TRC102 and Temodar  Glioblastoma - cancer
# EBS    VLA1601  Zika vaccine
# PFE    Glasdegib  Acute myeloid leukemia (AML)
# ABBV   Venclexta  First line unfit AML
# RHHBY  Venclexta  First line unfit AML
# NVO    Semaglutide - oral - PIONEER  Type 2 diabetes
# GTHX   Trilaciclib plus Tecentriq  First-line small-cell lung cancer
# BMY    CM-451 – Opdivo + Yervoy First-line Small cell lung cancer (SCLC)
# LOXO   Larotrectinib (LOXO-101)  Solid tumors that harbor a TRK fusion.
# VRTX   VX-659 in combination with tezacaftor and ivacaftor  Cystic fibrosis (CF) who have one F508del mutation and one minimal function mutation (F508del/Min)
# VRTX   VX-659 in combination with tezacaftor and ivacaftor  Cystic Fibrosis Who Have Two Copies of the F508del Mutation
# CPRX   Firdapse  Lambert-Easton Myasthenic Syndrome (LEMS)
# TEVA   TRUXIMA  Rituxan (rituximab) biosimilar
# ALKS   ALKS 3831 - ENLIGHTEN-2  Schizophrenia
# DVAX   AZD1419  Asthma
# VNDA   Tradipitant  Gastroparesis
# SNNA   SNA-120  Pruritus associated with psoriasis
# RDHL   RHB-105 - ERADICATE Hp 2  H. pylori
# OCUL   DEXTENZA  Ocular inflammation and pain following cataract surgery
# BHVN   Zydis ODT formulation of rimegepant  Migraine
# GTHX   Trilaciclib  Triple-negative breast cancer
# CNAT   Emricasan  NASH cirrhosis - ENCORE-PH trial
# ABBV   Rova-T (TAHOE)  Second-line Small Cell Lung Cancer
# PBYI   Neratinib SUMMIT  HER2 non-amplified breast cancer that has a HER2 mutation
# BYSI   Plinabulin (Trial 105)  Chemotherapy-induced neutropenia (CIN)
# SUPN   SPN-812  ADHD
# RHHBY  Tecentriq + Avastin - IMpower150  Non-squamous non-small cell lung cancer (NSCLC)
# AZN    Durvalumab +/- tremelimumab (EAGLE)  Head & neck cancer
#
#            Stage  \
# SPPI   CRL
# ZGNX   Approved
# ARDM   Approved
# SPPI   CRL
# SPPI   Approved
# PRTK   Approved
# GTXI   CRL
# HEB    CRL
# FCSC   Approved
# ACOR   -
# ALKS   Approved
# MNKD   Approved
# ALKS   Approved
# HRTX   Approved
# CTIC   Phase 3
# ARLZ   Approved
# JAZZ   Approved
# VVUS   Approved
# MNKD   Approved
# DEPO   Approved
# PLX    Approved
# SPPI   Approved
# FCSC   Approved
# DRRX   CRL
# PTIE   CRL
# SGEN   Approved
# PCRX   Approved
# ALIM   Approved
# INCY   Approved
# PRTK   Approved
# ...         ...
# ARQL   Phase 1
# AQST   CRL
# TCON   Phase 2
# EBS    Phase 1
# PFE    Approved
# ABBV   Approved
# RHHBY  Approved
# NVO    Phase 3
# GTHX   Phase 2
# BMY    Phase 3
# LOXO   Approved
# VRTX   Phase 3
# VRTX   Phase 3
# CPRX   Approved
# TEVA   Approved
# ALKS   Phase 3
# DVAX   Phase 2a
# VNDA   Phase 2
# SNNA   Phase 2b
# RDHL   Phase 3
# OCUL   Approved
# BHVN   Phase 3
# GTHX   Phase 2
# CNAT   Phase 2
# ABBV   Phase 3
# PBYI   Phase 2
# BYSI   Phase 2/3
# SUPN   Phase 3
# RHHBY  Approved
# AZN    Phase 3
#
#                                                                                                                                                                                               Catalyst  \
# SPPI     CRL received July 5, 2009.
# ZGNX     Approved July 16, 2009.
# ARDM     Approval granted July 16, 2009.
# SPPI     Approved September 4, 2009.
# SPPI     CRL received October 9, 2009.
# PRTK     CRL issued November 2, 2009.
# GTXI     CRL issued November 2, 2009.
# HEB      CRL issued December 1, 2009.
# FCSC     CRL issued December 18, 2009.
# ACOR     Approved January 22, 2010.
# ALKS     Approved January 27, 2010.
# MNKD     CRL issued March 15, 2010.
# ALKS     CRL received March 15, 2010.
# HRTX     CRL issued March 19, 2010.
# CTIC     CRL received April 9, 2010.
# ARLZ     Approved April 30, 2010.
# JAZZ     CRL received October 11, 2010.
# VVUS     October 28, 2010.
# MNKD     CRL received January 19, 2011.
# DEPO     Approved January 28, 2011.
# PLX      CRL issued February 25, 2011.
# SPPI     Approved April 29, 2011.
# FCSC     Approved June 22, 2011.
# DRRX     CRL received June 24, 2011.
# PTIE     CRL received June 24, 2011.
# SGEN     Approval announced August 19, 2011.
# PCRX     Approved October 31, 2011.
# ALIM     CRL November 2011.
# INCY     Approved November 16, 2011.
# PRTK     Approved November 23, 2011.
# ...                              ...
# ARQL     Phase 1 data released November 16, 2018. 9% partial response rate.
# AQST     CRL issued November 16, 2018.
# TCON     Phase 2 primary endpoint not met - November 19, 2018.
# EBS      Phase 1 data released November 19, 2018 - primary endpoint met with favorable safety profile.
# PFE      FDA approval announced November 21, 2018.
# ABBV     FDA approval announced November 21, 2018.
# RHHBY    FDA approval announced November 21, 2018.
# NVO      Final PIONEER trial data released November 23, 2018. Primary inferiority endpoint met. Reduction in MACE did not reach statistical significance.
# GTHX     Phase 2 data released November 26, 2018. ORR trilaciclib 56.0%, placebo 63.5%.
# BMY      Phase 3 trial did not meet primary endpoint - November 26, 2018.
# LOXO     FDA Approval announced November 26, 2018.
# VRTX     Phase 3 positive data released November 27, 2018. 14% improvement in ppFEV1 cf placebo.
# VRTX     Phase 3 positive data released November 27, 2018. 10% improvement in ppFEV1 cf placebo.
# CPRX     FDA approval announced November 28, 2018.
# TEVA     FDA Approval announced November 28, 2018.
# ALKS     Phase 3 data released November 29, 2018 met co-primary endpoints. NDA filing due mid-2019.
# DVAX     Phase 2a trial did not meet primary endpoint - November 29, 2018.
# VNDA     Phase 2 primary endpoint met - December 3, 2018.
# SNNA     Phase 2b trial did not meet primary endpoint. Phase 3 trial to be initiated 2H 2019.
# RDHL     Phase 3 trial met primary endpoint. NDA filing 1H 2019.
# OCUL     FDA approval announced December 3, 2018.
# BHVN     Phase 3 data released December 3, 2018 - primary endpoints met.
# GTHX     Phase 2 preliminary data noted ORR 37-43% across two arms. No CRs. PFS 8.8mths (HR 0.52, p=0.0669) and 7.3mths (HR 0.49; p=0.0546) across two arms. Combined PFS 7.9mths (HR 0.50, p=0.0189).
# CNAT     Phase 2b data released December 5, 2018 did not meet primary endpoint.
# ABBV     Phase 3 enrolment to be stopped due to shorted overall survival following recommendation from Independent Data Monitoring Committee (IDMC) December 5, 2018.
# PBYI     Phase 2 data released December 6, 2018 noted ORR 30%; 9% CR.
# BYSI     Phase 3 trial met primary endpoint of non-inferiority vs Neulasta. NDA filing planned.
# SUPN     Phase 3 data from two of its trials released December 6, 2018 met primary endpoints but with concerns regarding effect size vs competition. Data from adolescent trial due 1Q 2019.
# RHHBY    FDA Approval announced December 6, 2018.
# AZN      Phase 3 data released December 7, 2018 - primary endpoints not met.
#
#             Date       Past     Future
# SPPI  2009-07-05 2009-06-14 2009-07-12
# ZGNX  2009-07-16 2009-06-25 2009-07-23
# ARDM  2009-07-16 2009-06-25 2009-07-23
# SPPI  2009-09-04 2009-08-14 2009-09-11
# SPPI  2009-10-09 2009-09-18 2009-10-16
# PRTK  2009-11-02 2009-10-12 2009-11-09
# GTXI  2009-11-02 2009-10-12 2009-11-09
# HEB   2009-12-01 2009-11-10 2009-12-08
# FCSC  2009-12-18 2009-11-27 2009-12-25
# ACOR  2010-01-22 2010-01-01 2010-01-29
# ALKS  2010-01-27 2010-01-06 2010-02-03
# MNKD  2010-03-15 2010-02-22 2010-03-22
# ALKS  2010-03-15 2010-02-22 2010-03-22
# HRTX  2010-03-19 2010-02-26 2010-03-26
# CTIC  2010-04-09 2010-03-19 2010-04-16
# ARLZ  2010-04-30 2010-04-09 2010-05-07
# JAZZ  2010-10-11 2010-09-20 2010-10-18
# VVUS  2010-10-28 2010-10-07 2010-11-04
# MNKD  2011-01-19 2010-12-29 2011-01-26
# DEPO  2011-01-28 2011-01-07 2011-02-04
# PLX   2011-02-25 2011-02-04 2011-03-04
# SPPI  2011-04-29 2011-04-08 2011-05-06
# FCSC  2011-06-22 2011-06-01 2011-06-29
# DRRX  2011-06-24 2011-06-03 2011-07-01
# PTIE  2011-06-24 2011-06-03 2011-07-01
# SGEN  2011-08-19 2011-07-29 2011-08-26
# PCRX  2011-10-31 2011-10-10 2011-11-07
# ALIM  2011-11-11 2011-10-21 2011-11-18
# INCY  2011-11-16 2011-10-26 2011-11-23
# PRTK  2011-11-23 2011-11-02 2011-11-30
# ...          ...        ...        ...
# ARQL  2018-11-16 2018-10-26 2018-11-23
# AQST  2018-11-16 2018-10-26 2018-11-23
# TCON  2018-11-19 2018-10-29 2018-11-26
# EBS   2018-11-19 2018-10-29 2018-11-26
# PFE   2018-11-21 2018-10-31 2018-11-28
# ABBV  2018-11-21 2018-10-31 2018-11-28
# RHHBY 2018-11-21 2018-10-31 2018-11-28
# NVO   2018-11-23 2018-11-02 2018-11-30
# GTHX  2018-11-26 2018-11-05 2018-12-03
# BMY   2018-11-26 2018-11-05 2018-12-03
# LOXO  2018-11-26 2018-11-05 2018-12-03
# VRTX  2018-11-27 2018-11-06 2018-12-04
# VRTX  2018-11-27 2018-11-06 2018-12-04
# CPRX  2018-11-28 2018-11-07 2018-12-05
# TEVA  2018-11-28 2018-11-07 2018-12-05
# ALKS  2018-11-29 2018-11-08 2018-12-06
# DVAX  2018-11-29 2018-11-08 2018-12-06
# VNDA  2018-12-03 2018-11-12 2018-12-10
# SNNA  2018-12-03 2018-11-12 2018-12-10
# RDHL  2018-12-03 2018-11-12 2018-12-10
# OCUL  2018-12-03 2018-11-12 2018-12-10
# BHVN  2018-12-03 2018-11-12 2018-12-10
# GTHX  2018-12-04 2018-11-13 2018-12-11
# CNAT  2018-12-05 2018-11-14 2018-12-12
# ABBV  2018-12-05 2018-11-14 2018-12-12
# PBYI  2018-12-06 2018-11-15 2018-12-13
# BYSI  2018-12-06 2018-11-15 2018-12-13
# SUPN  2018-12-06 2018-11-15 2018-12-13
# RHHBY 2018-12-06 2018-11-15 2018-12-13
# AZN   2018-12-07 2018-11-16 2018-12-14
#
# [1620 rows x 6 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 3.0, 0.01)

ax1 = plt.subplot(212)
ax1.margins(0,-0.2)           # Default margin is 0.05, value 0 means fit
ax1.plot(t1, f(t1), 'k')



plt.show()
